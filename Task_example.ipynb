# %%
import json
import pandas as pd
path = 'three_minutes_tweets.json.txt'

# %% [markdown]
# # Как и говорил Вам, обожаю сайт: stackoverflow.com. https://stackoverflow.com/questions/21058935/python-json-loads-shows-valueerror-extra-data
# ## Придумывать что-то своё я также люблю, не меньше :)

# %%
# with open(path, 'r') as f:
#     data = json.loads(json.dumps(f.read()))
#     a = json.load (data)
# print (data[:1000])
tweets = []
name = []
tweet_text = []
country_code = []
display_url = []
lang = []
created_at = []
location = []

for line in open(path, 'r'):
    tweets.append(json.loads(line))
for i in range (1, len(tweets)):
    
    if 'delete' not in tweets[i]: 
#         print (i)
        name.append (tweets[i]['user']['name'])
        tweet_text.append (tweets[i]['text'])
        country_code.append (tweets[i]['user']['location']) # 'location'?
        lang.append (tweets[i]['lang'])
        created_at.append(tweets[i]['created_at'])
        location.append(tweets[i]['user']['location'])
        if not tweets[i]['entities']['urls']:
            display_url.append ("None")
        else:
            display_url.append (tweets[i]['entities']['urls'][0]['display_url'])

print (len(name))
print (len(tweet_text))
print (len(country_code))
print (len(lang))
print (len(created_at))
print (len(location))
print (len(display_url))

# print (name [:2])
# print (tweets[2]) #['user'] ['screen_name'] #['created_at'] #такой подойдёт?
# print ('delete' in tweets[29]) #0,29 -- False 102 - Russian language
# Out:
# 7338
# 7338
# 7338
# 7338
# 7338
# 7338
# 7338

# %%
# 'tweet_sentiment':tweet_sentiment
dictio = {'name': name,
                  'tweet_text': tweet_text,
                  'country_code' : country_code,
                  'lang':lang,
                  'created_at': created_at,
                  'location': location,
                  'display_url': display_url,
                  
                 }
df1 = pd.DataFrame.from_dict(dictio)
print (df1)
# Out:
#                       name                                         tweet_text  \
# 0     شخصيه دبلوِماسيّة.!ّ                                        ايه الأكل 😜
# 1                   styles  RT @nitishuna: @LasVegasChicas @I_luv_reds @Di...
# 2                   اقتباس  إنّ العرب إذا تغلبوا على أوطان أسرع إليها الخر...
# 3               N.ALSHAHRI  RT @moonmona7: لن الومك على رِحيلك ...\nفَـقٌـ...
# 4                 Braydoe                              @16_Pirates any shots?
# 5                   Halima  RT @Cancer_gk: A #Cancer may act shy and quiet...
# 6          Simona Marshall               @1voodoochild thanks for the follow💯
# 7                    仮面バニー  "shitting on otherkin is ablist and transphobi...
# 8                      pam                     112 #MTVHottest Britney Spears
# 9             عاصم الماوري  RT @Gggb769Gggb: هناك ضربه موجه  ستكون في عمق ...
# 10                       .  RT @BestofPisces: #Pisces won't always call yo...
# 11                  小布施 達亮  これ、これ！！！\nまじで50万楽勝だったwww\n　　【http://t.co/Q6oJ3...
# 12                なのめ(あおい)                               @tenu_san 実習です寝れません…
# 13                  Reegan     RT @TanBiitches: PREACH http://t.co/08TTjh7G01
# 14            ∞ KarenRaine  Boooa noiiiite,\n\nConverso com Deus porque se...
# 15                    seda  amk filmi beynimin içine etti ya düşünemiyorum...
# 16         Felino Perverso           RT @PerfectBaits: http://t.co/9Y8VAB9Gbq
# 17        Traci S Thompson  RT @quotes4writers: Elie Wiesel: Words can som...
# 18     oloco viih ou ste?               RT @marcusbrando: Tô carente de money
# 19                    ろーとん                                              ふぅ。ねみ
# 20               بنات دلع   تستحم و يصورها و هي خجلانا جديددددد + الصور &l...
# 21                   Lucia  RT @ana_auryneer: Voy a subir 15 fotos de Davi...
# 22                Bostera   RT @AcostaCelu: Ella me stalkea ♡ \n\nTe amo r...
# 23                   хёрди  самый любимый вайн с лм, где они говорят: лав ...
# 24          Jaymin Thakrar  @ShivamDRao are you dumb blud.... You have mis...
# 25                  Dɨɛɢʊɨ  RT @PolloVignolo: Coincido plenamente señor ga...
# 26                7amharry  ربي ارحمهما كما ربياني صغيرا\nhttp://t.co/lLjX...
# 27             Trap Queen   Naging malake ung uniform ko dahil sa buhol ko 😂😂
# 28                 bellamy  RT @oihanamarre: PTDDDDDDDDR LE PAUVRE http://...
# 29          BBP'ALPEREN#MY  RT @imamoglu53: Şerefsiz,alçaklar!\n\n#SavaşYo...
# ...                    ...                                                ...
# 7308    stefani dominguez   RT @OliveraKami: Bobisimaaa es tardeee lo esto...
# 7309     Waktu Solat Kulim  Telah masuk waktu Imsak (5:44) bagi kawasan Ku...
# 7310  not childish gambino  Niggas talk on twitter but in life they don't ...
# 7311            Uma Flor ❁                                           Só pode!
# 7312                    えむ                        にしてもほんと…あの2000形の折り返し芸やばすぎた…
# 7313  @vJapa_x segue lá pf  Gostei de um vídeo do @YouTube de @mudinhogame...
# 7314          ♛VERSATILE♛™  If we really want to love we must learn how to...
# 7315                   あかり    @mikaa613 旅行最終日もそのまま飲み会に直行する意識の高さ✧＼\ ٩ ⍤⃝ و /／✧
# 7316                 Anto♡                            Por fin celular nuevo👏👏
# 7317          Wagner Brito  O que importa é que meu time no Top Eleven gan...
# 7318          mahmut tetik  RT @nuraysayarii: Haftalık Burç Yorumu http://...
# 7319            Megan [PB]  RT @PointlessBlog: NEW VIDEO https://t.co/Tyv7...
# 7320          BAYAN KİRPİK  RT @nuraysayarii: Haftalık Burç Yorumu http://...
# 7321        William Butler    Be committed to social justice. #5WordsOfWisdom
# 7322        Joe DeMaria Jr  RT @DetroitPodcast: Aware.....I mean I'm not s...
# 7323              酔いどれひぐりん          酔いどれひぐりんブログ: 夏休み終了 http://t.co/gUwbp8wMr8
# 7324                  gaga  179- #MTVSummerStar #MTVHottest Lady Gaga 🌲 Ri...
# 7325     HITANA ENFURESÍAH  Lo bueno es que no hace esculpirle un rostro j...
# 7326          Lorena Nunes  I only wanna die alive, never by the hands of ...
# 7327          نوال الشهري   انجاز احدث سجن بموصفات عالمية في السعودية (اصل...
# 7328                sheesh                                            P T D R
# 7329       Половцев Кирилл  @VPlacha \nИнтересуют лекции по духовному разв...
# 7330          مراهقة ساخنة  زنقها في البدروم وفشخها نيك\nشاهد: http://t.co...
# 7331                レウス@神。  TYOIR:＠null http://t.co/eF5Coqksap←RTしてね(prz) ...
# 7332  vinicius felipe padi  @mateiformiga Parabéns mano seus videos são mt...
# 7333                Tommo.  Nobody wants to talk to me. I'm a shit. Deleting.
# 7334                 مكوتى  يدخل على بنته في الغرفة وينيكهاhttp://t.co/BoC...
# 7335    Mrs Hinata ✽ なやで✽   RT @rtursugawara: suga (advocate of world peac...
# 7336       Sam McClafferty                    @SportsRadioWIP @PhilaUnion wow
# 7337         Manuel (neko)  @TetoKasane11 yo igual soy un neko hermana,nya...
#
#                        country_code lang                      created_at  \
# 0                                     ar  Sun Aug 16 21:41:13 +0000 2015
# 1                                    und  Sun Aug 16 21:41:13 +0000 2015
# 2                                     ar  Sun Aug 16 21:41:13 +0000 2015
# 3                    ‏​‏​‏​‏​‏​‏​‏​   ar  Sun Aug 16 21:41:13 +0000 2015
# 4                                     en  Sun Aug 16 21:41:13 +0000 2015
# 7332                                  pt  Sun Aug 16 21:44:03 +0000 2015
# 7333                |Single|Bi|DMs|   en  Sun Aug 16 21:44:03 +0000 2015
# 7334                                  ar  Sun Aug 16 21:44:03 +0000 2015
# 7335           Fangirleando por ahí   en  Sun Aug 16 21:44:03 +0000 2015
# 7336                                 und  Sun Aug 16 21:44:03 +0000 2015
# 7337                 vivo en narnia   es  Sun Aug 16 21:44:03 +0000 2015
#
#                            location                                display_url
# 0                                                                         None
# 1                                                                         None
# 2                                                                         None
# 3                    ‏​‏​‏​‏​‏​‏​‏​                                       None
# 4                                                                         None
# 5                 Khulna,Bangladesh                                       None
# 6                 North Little Rock                                       None
# 7                                                                         None
# 8                                                                         None
# 9                                                                         None
# 10                  with YO bitch !                                       None
# 11                                                              bit.ly/1eFO2qs
# 12                          Twitter                                       None
# 13                                                                        None
# 14                      Santo André                                       None
# 15                            bursa                                       None
# 16                                                                        None
# 17                      Abilene, TX                                       None
# 18                       Manaus-AM                                        None
# 19                           静岡時々大阪                                       None
# 20                                   myocardia25l.blogspot.com/2015/07/myocar…
# 21                                                                        None
# 22                                                                        None
# 23                           chains                                       None
# 24                           London                                       None
# 25          Buenos Aires, Argentina                twitter.com/dflatorre/stat…
# 26                                                           i-qra.com/t/1927/
# 27                              bby                                       None
# 28                       solene  #c                                       None
# 29                            Dünya                                       None
# ...                             ...                                        ...
# 7308                                                                      None
# 7309                                                                      None
# 7310                                                                      None
# 7311                                                                      None
# 7312                  まぐろ・カレー・軍港の半島                                       None
# 7313                                                    youtu.be/IXns24_LWpA?a
# 7314                      WORLDWIDE                                       None
# 7315                                                                      None
# 7316                                                                      None
# 7317          Rio Claro, SP, Brasil                                       None
# 7318                                           nuraysayari.org/haftalik-burc-…
# 7319                                                      youtu.be/sP2f0eFpA68
# 7320                                           nuraysayari.org/haftalik-burc-…
# 7321     49°10' North, 121°55' West                                       None
# 7322                       Novi, MI                twitter.com/ironycladless/…
# 7323                            川崎市      higulin.at.webry.info/201508/article…
# 7324                                                                      None
# 7325  Creando a Boruto ( ͡° ͜ʖ ͡°)                                        None
# 7326                                             instagram.com/p/6dbQkODPGV1G…
# 7327                                                                      None
# 7328                Nancy, Lorraine                                       None
# 7329                                              facebook.com/notes/%D0%BA%D…
# 7330                                                            bit.ly/1Nzqqje
# 7331                         LINE運営                              goo.gl/Uk8FHU
# 7332                                                                      None
# 7333                |Single|Bi|DMs|                                       None
# 7334                                                 myocardia25l.blogspot.com
# 7335           Fangirleando por ahí                                       None
# 7336                                                                      None
# 7337                 vivo en narnia                                       None
#
# [7338 rows x 7 columns]

# %%
text_sentiment = "AFINN-111.txt"

import csv
word = []
mark = []
# создадим словарик для удобства
with open(text_sentiment) as f:
    reader = csv.reader(f, delimiter="\t")
    for i in list(reader):
        word.append(i[0])
        mark.append(i[1])
#         print (i)#(dict(zip(i)))
#     print (list(reader)[0])
#     d = dict(zip(list(reader)[0][0],list(reader)[0][1]))
#     d = dict(zip(list(reader)[0],list(reader)[1]))
# print (d) # 248
text_sentiment_dict = dict(zip(word, mark))

# %%
# print (text_sentiment_dict['abandon']) # it works
stroka = df1.loc[7326]['tweet_text']
spisok = stroka.split ()
tweet_sentiment_sum = 0
for i in spisok:
    if i in text_sentiment_dict:
        print (i)
        tweet_sentiment_sum += int(text_sentiment_dict[i])
print (tweet_sentiment_sum)
# Out:
# die
# broken
# -4
